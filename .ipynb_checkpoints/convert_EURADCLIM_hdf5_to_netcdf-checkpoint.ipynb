# %% [markdown]
# # Conversion HDF5->NetCDF des données EURADCLIM (radar)

# %% [raw]
# Jeu test récupéré sur hendrix : /home/caillaudc/OBS/EURADCLIM/h5

# %% [raw]
# 🧠 Ce l'on a  dans le fichier HDF5
# -----------------------------------
#
# 📊 Données
# shape : (2200, 1900) → (y, x)
# type : float32
# dataset : dataset1/data1/data
#
# 🗺️ Géométrie
#
# Dans where :
#
# projection :
#
# +proj=laea +lat_0=55 +lon_0=10 ...
#
# 👉 projection Lambert Azimuthal Equal Area
#
# grille :
# xsize = 1900
# ysize = 2200
# xscale = 2000 m
# yscale = 2000 m
#
# 👉 donc :
# ➡️ grille régulière en mètres
#
# 🌍 Coins géographiques (lat/lon)
#
# Il y a les 4 coins :
#
# LL, LR, UL, UR
#
# 👉 utile pour vérification, mais pas nécessaire pour construire la grille projetée
#
#
# ⚠️ Points à vérifier
# --------------------
#
# ✔️ Sens de Y
# si carte inversée → y = y[::-1] + data = data[::-1, :]
#
# ✔️ Données physiques
# On a pas : gain, offset
# 👉 donc probablement déjà en unités physiques 👍

# %% [markdown]
# ## 0 - Installation (venv + ipykernel)

# %% [raw]
# # creation d'un environnement virtuel (venv)
# python3.12 -m venv ~/virtual_envs/hdf5_venv
#
# # activation du venv
# source ~/virtual_envs/hdf5_venv/bin/activate
#
# # installation des dépendances
# pip install -r requirements.txt
#
# # création d'un kernel jupyter
# python -m ipykernel install --user --name hdf5_kernel
#
# # puis choisir ce kernel dans le jupyter-notebook

# %%
from pathlib import Path
import numpy as np
import h5py
import xarray as xr
import dask.array as da
import pandas as pd
from pyproj import CRS, Transformer
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import cartopy.crs as ccrs
import copy

# %% [markdown]
# ## 1- Paramètres utilisateur

# %%
#================================================
PROJ = "EURADCLIM"
PROD = "RAD_OPERA"
VAR = "HOURLY_RAINFALL_ACCUMULATION"
#YEAR = "2013"
#MONTH = "01"
#DAY = "23"
#HOUR = "15"
YEAR = "2020"
MONTH = "10"
DAY = "02"
HOUR = "14"
TIMESTAMP = f"{YEAR}{MONTH}{DAY}{HOUR}00"
#ECHEANCE = f"{YEAR}-{MONTH}-{DAY} {HOUR}:00:00"
ECHEANCE = pd.to_datetime(TIMESTAMP, format="%Y%m%d%H%M")

# Fichier d'entrée (HDF5)
path_in = f"/data/scratch/globc/moine/obs_data/{PROJ}/test/{PROJ}_data/{PROD}_{VAR}_EURADCLIM/{YEAR}/{MONTH}"
pi = Path(path_in)
fname_in = f"{PROD}_{VAR}_{TIMESTAMP}.h5"
input_hdf5 = '/'.join([path_in, fname_in])
varname_in = "variable" # nom générique

# Fichier de sortie (NetCDF) pour 1 seule échéace (1h)
path_out = "/".join([path_in, "netcdf"])
po = Path(path_out)
if not po.exists(): po.mkdir()
fname_out = f"{PROD}_{VAR}_{TIMESTAMP}.nc"
output_netcdf="/".join([path_out,fname_out])

# Fichier de sortie (NetCDF) pour la time-serie du mois
TIMESTAMP_TS = f"{YEAR}{MONTH}"
fname_out_ts = f"{PROD}_{VAR}_{TIMESTAMP_TS}.nc"
output_netcdf_ts = "/".join([path_out,fname_out_ts])

varname_out = VAR
#================================================

# %%
print(input_hdf5)
# Out:
# /data/scratch/globc/moine/obs_data/EURADCLIM/test/EURADCLIM_data/RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_EURADCLIM/2020/10/RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010021400.h5

# %%
print(output_netcdf)
# Out:
# /data/scratch/globc/moine/obs_data/EURADCLIM/test/EURADCLIM_data/RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_EURADCLIM/2020/10/netcdf/RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010021400.nc

# %% [markdown]
# ## 2- Exploration du fichier HDF5

# %%
def explore(name, obj):
    print(name)

with h5py.File(input_hdf5, "r") as f:
    f.visititems(explore)
# Out:
# dataset1
# dataset1/data1
# dataset1/data1/data
# dataset1/what
# how
# what
# where

# %%
with h5py.File(input_hdf5, "r") as f:
    d = f["dataset1/data1/data"]
    print(d.shape, d.dtype)
    # dict -> pour pouvoir les réutilser hors du with
    how = dict(f["how"].attrs) 
    where = dict(f["where"].attrs)
    what = dict(f["what"].attrs)
# Out:
# (2200, 1900) float64

# %%
print(how)
# Out:
# {'nodes': np.bytes_(b'NOD:fikuo,NOD:chwei,NOD:sella,NOD:frniz,NOD:chppm,NOD:dedrs,NOD:sklaz,NOD:frbol,NOD:deneu,NOD:deoft,NOD:ukdud,NOD:esbad,NOD:frlep,NOD:eesur,NOD:frtre,NOD:ukche,NOD:skjav,NOD:ukdea,NOD:rotim,NOD:frmom,NOD:ukmun,NOD:robuc,NOD:defld,NOD:ukthu,NOD:fikor,NOD:fikes,NOD:nlhrw,NOD:frbou,NOD:czska,NOD:deess,NOD:robob,NOD:seang,NOD:fipet,NOD:chdol,NOD:filuo,NOD:frmcl,NOD:defbg,NOD:fraja,NOD:deros,NOD:frmtc,NOD:dehnr,NOD:uking,NOD:ukham,NOD:sehuv,NOD:escor,NOD:deboo,NOD:deeis,NOD:iskef,NOD:denhb,NOD:sipas,NOD:plbrz,NOD:demem,NOD:frgre,NOD:plram,NOD:frche,NOD:frtou,NOD:frnan,NOD:deasb,NOD:nldhl,NOD:eszar,NOD:husze,NOD:frcae,NOD:bewid,NOD:ukhhd,NOD:norsa,NOD:ukhmy,NOD:frpla,NOD:essan,NOD:fropo,NOD:deumd,NOD:uklew,NOD:dksin,NOD:frtro,NOD:frbla,NOD:esmad,NOD:fiika,NOD:seoer,NOD:frabb,NOD:frave,NOD:norst,NOD:finur,NOD:seatv,NOD:iesha,NOD:depro,NOD:nober,NOD:fivim,NOD:esmal,NOD:nobml,NOD:ukcas,NOD:nohgb,NOD:ptlis,NOD:hrzag,NOD:skkub,NOD:plgda,NOD:frtra,NOD:frbor,NOD:frale,NOD:dkste,NOD:ukjer,NOD:sebaa,NOD:bejab,NOD:ukcle,NOD:frnim,NOD:dkbor,NOD:fivan,NOD:ukcyg,NOD:fiuta,NOD:nosta,NOD:fianj,NOD:rocra,NOD:detur,NOD:ptprt,NOD:hunap,NOD:ukcob,NOD:sevax,NOD:sehem,NOD:eehar,NOD:chalb,NOD:dkvir,NOD:frcol,NOD:rsjas,NOD:ukpre,NOD:hrosi,NOD:ptfar,NOD:nohur,NOD:chlem,NOD:robar,NOD:sekaa,NOD:esalm,NOD:eslpa,NOD:dkrom,NOD:roora,NOD:skkoj,NOD:espma,NOD:hubud,NOD:isegs,NOD:selek,NOD:hupog,NOD:nohas,NOD:plpas,NOD:plleg,NOD:romed,NOD:nosmn,NOD:czbrd,NOD:nohfj,NOD:hrbil,NOD:eslid,NOD:plpoz,NOD:plrze,NOD:plswi,NOD:esbar,NOD:silis,NOD:noand,NOD:essev,NOD:esmur')}

# %%
print(where)
# Out:
# {'LL_lat': np.float64(31.746215319325056), 'LL_lon': np.float64(-10.434576838640398), 'LR_lat': np.float64(31.98765027794496), 'LR_lon': np.float64(29.421038635578032), 'UL_lat': np.float64(67.02283275830867), 'UL_lon': np.float64(-39.5357864125034), 'UR_lat': np.float64(67.62103710275053), 'UR_lon': np.float64(57.81196475014995), 'projdef': np.bytes_(b'+proj=laea +lat_0=55.0 +lon_0=10.0 +x_0=1950000.0 +y_0=-2100000.0 +units=m +ellps=WGS84'), 'xscale': np.float64(2000.0), 'xsize': np.uint64(1900), 'yscale': np.float64(2000.0), 'ysize': np.uint64(2200)}

# %%
print(what)
# Out:
# {'date': np.bytes_(b'20201002'), 'object': np.bytes_(b'COMP'), 'source': np.bytes_(b'ORG:247'), 'time': np.bytes_(b'140000'), 'version': np.bytes_(b'H5rad 2.0')}

# %% [markdown]
# ### Extraction d'attributs de grille/projection utiles

# %%
proj4 = where["projdef"]
if isinstance(proj4, bytes):
    proj4 = proj4.decode()

# ATTENTION: crs.CRS.from_proj4() retourne souvent un objet pyproj-like encapsulé, 
# mais pas toujours une projection “Matplotlib-ready”.
crs_proj = CRS.from_proj4(proj4) 
proj_params = crs_proj.to_dict()

crs_geo = CRS.from_epsg(4326)

# CHECK
print(type(crs_proj))
print(crs_proj)

print(type(crs_geo))
print(crs_geo)

ellps = str(proj_params.get("ellps", "AUCUN"))

x0 = float(proj_params.get("x_0", 0.0))
y0 = float(proj_params.get("y_0", 0.0))

lon0 = float(proj_params.get("lon_0", 0.0))
lat0 = float(proj_params.get("lat_0", 0.0))

nx = int(where["xsize"])
ny = int(where["ysize"])

dx = float(where["xscale"])
dy = float(where["yscale"])
# Out:
# <class 'pyproj.crs.crs.CRS'>
# +proj=laea +lat_0=55.0 +lon_0=10.0 +x_0=1950000.0 +y_0=-2100000.0 +units=m +ellps=WGS84 +type=crs
# <class 'pyproj.crs.crs.CRS'>
# EPSG:4326
# /data/scratch/globc/moine/virtual_envs/hdf5_venv/lib64/python3.12/site-packages/pyproj/crs/crs.py:1295: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)

# %% [markdown]
# ### Coordonnées brutes (x,y) et (lon,lat) reconstituées avec pyproj

# %%
x = x0 + np.arange(nx) * dx
y = y0 - np.arange(ny) * dy

transformer = Transformer.from_crs(crs_proj, crs_geo, always_xy=True)
X, Y = np.meshgrid(x, y)

lon_rebuilt, lat_rebuilt = transformer.transform(X, Y)

# %% [markdown]
# ### Récupération des coordonnées  (lon, lat) fournies avec EURADCLIM

# %%
arr = np.loadtxt("CoordinatesHDF5ODIMWGS84.dat")

lon_exact = arr[:, 0].reshape(ny, nx)
lat_exact = arr[:, 1].reshape(ny, nx)

# %% [markdown]
# ### Valeur manquante

# %%
FILL = -9.9990e+06

# %% [markdown]
# ## 3- Conversion en NetCDF (1 seule échéance horaire)

# %%
# utilisation des coordonnées lat/lon ou x/y
latlon_coords = True

# utilisation des lat/lon exactes fournies avec EURADCLIM
latlon_exact = True

# -------------------------
# 1. Lecture HDF5
# -------------------------

with h5py.File(input_hdf5, "r") as f:
    data = f["dataset1/data1/data"][:]
    where = dict(f["where"].attrs) # dict -> pour pouvoir le réutilser hors du with
print(where)

# Gestion des Nan
data = data.astype("float32")
data[data == FILL] = np.nan

# Création d'une variable time au standard
time = pd.to_datetime(TIMESTAMP, format="%Y%m%d%H%M")

# -------------------------
# 2. Grille
# -------------------------

# attributs du where:
#{'LL_lat': np.float64(31.746215319325056), 
# 'LL_lon': np.float64(-10.434576838640398), 
# 'LR_lat': np.float64(31.98765027794496), 
# 'LR_lon': np.float64(29.421038635578032), 
# 'UL_lat': np.float64(67.02283275830867), 
# 'UL_lon': np.float64(-39.5357864125034), 
# 'UR_lat': np.float64(67.62103710275053), 
# 'UR_lon': np.float64(57.81196475014995), 
# 'projdef': np.bytes_(b'+proj=laea +lat_0=55.0 +lon_0=10.0 +x_0=1950000.0 +y_0=-2100000.0 +units=m +ellps=WGS84'), 
# 'xscale': np.float64(2000.0), 
# 'xsize': np.uint64(1900), 
# 'yscale': np.float64(2000.0),  
# 'ysize': np.uint64(2200)}

# ajuster si besoin après test visuel
# data = data[::-1, :]
# y = y[::-1]

# -------------------------
# 3. Projection → lat/lon
# -------------------------

if latlon_exact:
    lon = copy.deepcopy(lon_exact)
    lat = copy.deepcopy(lat_exact)  
else:
    lon = copy.deepcopy(lon_rebuilt)
    lat = copy.deepcopy(lat_rebuilt)

# -------------------------
# 4. Dataset xarray
# -------------------------

if latlon_coords:     
    ds = xr.Dataset(
        data_vars=dict(
            variable=(("y", "x"), data)
        ),
        coords=dict(
            time=("time", [time]),
            lon=(("y", "x"), lon),
            lat=(("y", "x"), lat),
        ),
    )
else:
    ds = xr.Dataset(
        data_vars=dict(
            variable=(("y", "x"), data)
        ),
        coords=dict(
            time=("time", [time]),
            x=("x", x),
            y=("y", y),
        ),
    )
    
print(ds)

# -------------------------
# 5. Attributs CF
# -------------------------

if latlon_coords:  
    ds["lon"].attrs = {
        "standard_name": "longitude",
        "units": "degrees_east"
    }

    ds["lat"].attrs = {
        "standard_name": "latitude",
        "units": "degrees_north"
    }
else:
    ds["x"].attrs = {
        "standard_name": "projection_x_coordinate",
        "units": "m"
    }

    ds["y"].attrs = {
        "standard_name": "projection_y_coordinate",
        "units": "m"
    }


CF_VARIABLES = {
    "HOURLY_RAINFALL_ACCUMULATION": {
        "standard_name": "lwe_thickness_of_precipitation_amount",
        "long_name": "Hourly accumulated rainfall",
        "units": "kg m-2",
        "grid_mapping": "crs",
        "coordinates": "lat lon"
    }
}

ds = ds.rename({varname_in: varname_out})

attrs = CF_VARIABLES[varname_out]

ds[varname_out].attrs.update(attrs)

# -------------------------
# 6. CRS
# -------------------------

ds["crs"] = xr.DataArray()
ds["crs"].attrs = {
    "grid_mapping_name": "lambert_azimuthal_equal_area",
    "spatial_ref": proj4
}
print(ds)

# -------------------------
# 7. Export
# -------------------------

ds.to_netcdf(output_netcdf, format="NETCDF4")
# Out:
# {'LL_lat': np.float64(31.746215319325056), 'LL_lon': np.float64(-10.434576838640398), 'LR_lat': np.float64(31.98765027794496), 'LR_lon': np.float64(29.421038635578032), 'UL_lat': np.float64(67.02283275830867), 'UL_lon': np.float64(-39.5357864125034), 'UR_lat': np.float64(67.62103710275053), 'UR_lon': np.float64(57.81196475014995), 'projdef': np.bytes_(b'+proj=laea +lat_0=55.0 +lon_0=10.0 +x_0=1950000.0 +y_0=-2100000.0 +units=m +ellps=WGS84'), 'xscale': np.float64(2000.0), 'xsize': np.uint64(1900), 'yscale': np.float64(2000.0), 'ysize': np.uint64(2200)}
# <xarray.Dataset> Size: 84MB
# Dimensions:   (y: 2200, x: 1900, time: 1)
# Coordinates:
#     lon       (y, x) float64 33MB -39.5 -39.47 -39.43 ... 29.37 29.39 29.41
#     lat       (y, x) float64 33MB 67.02 67.03 67.05 67.06 ... 32.01 32.0 32.0
#   * time      (time) datetime64[us] 8B 2020-10-02T14:00:00
# Dimensions without coordinates: y, x
# Data variables:
#     variable  (y, x) float32 17MB nan nan nan nan nan ... nan nan nan nan nan
# <xarray.Dataset> Size: 84MB
# Dimensions:                       (y: 2200, x: 1900, time: 1)
# Coordinates:
#     lon                           (y, x) float64 33MB -39.5 -39.47 ... 29.41
#     lat                           (y, x) float64 33MB 67.02 67.03 ... 32.0 32.0
#   * time                          (time) datetime64[us] 8B 2020-10-02T14:00:00
# Dimensions without coordinates: y, x
# Data variables:
#     HOURLY_RAINFALL_ACCUMULATION  (y, x) float32 17MB nan nan nan ... nan nan
#     crs                           float64 8B nan

# %%
ds
# Out:
# <xarray.Dataset> Size: 84MB
# Dimensions:                       (y: 2200, x: 1900, time: 1)
# Coordinates:
#     lon                           (y, x) float64 33MB -39.5 -39.47 ... 29.41
#     lat                           (y, x) float64 33MB 67.02 67.03 ... 32.0 32.0
#   * time                          (time) datetime64[us] 8B 2020-10-02T14:00:00
# Dimensions without coordinates: y, x
# Data variables:
#     HOURLY_RAINFALL_ACCUMULATION  (y, x) float32 17MB nan nan nan ... nan nan
#     crs                           float64 8B nan

# %% [markdown]
# ## 3a - Plot du HDF5 en (x,y)

# %%
with h5py.File(input_hdf5, "r") as f:
    data = f["dataset1/data1/data"][:]
    where = dict(f["where"].attrs) # dict -> pour pouvoir le réutilser hors du with

# %%
#data_hdf5 = data_plot
data_hdf5 = copy.deepcopy(data)

# %%
# éviter les valeurs négatives, nulles et Nan
data_hdf5_plot = data_hdf5.astype(float)
data_hdf5_plot[(data_hdf5 <= 0) | (data_hdf5 == FILL)] = np.nan

# %%
plot_label = "Rainfall (mm/h)"
plot_title = "Raw HDF5 data - Rainfall (log scale)"
log_norm = colors.LogNorm(vmin=0.01, vmax=120)

# %%
plt.figure()

plt.imshow(
    data_hdf5_plot, 
    origin="upper", # important !
    norm=log_norm,
    cmap="turbo",
    aspect="equal"
    ) 
    
plt.colorbar(label=plot_label)
plt.title(plot_title)
plt.xlabel("x")
plt.ylabel("y")

plt.show()

# %% [markdown]
# ### Ajout des contours des continents sur le plot HDF5 (x,y) ---> PB Localisation dans la projection LAEA

# %%
print(lon0)
# Out:
# 10.0

# %%
plt.figure()

# ATTENTION: crs.CRS.from_proj4() retourne souvent un objet pyproj-like encapsulé, 
# mais pas toujours une projection “Matplotlib-ready”.
#proj = ccrs.CRS.from_proj4(proj4) 

# MEILLEURE SOLUTION: reconstruire de la projection explicitement en Cartopy (sans passer par proj4)
proj = ccrs.LambertAzimuthalEqualArea(
    central_longitude=lon0,
    central_latitude=lat0,
    false_easting=x0,
    false_northing=y0,
    globe=ccrs.Globe(ellipse=ellps)
)
#proj = ccrs.PlateCarree()

# CHECK
print(type(proj))
print(proj)

ax = plt.axes(projection=proj)

# ATTENTION: transform=proj ne marche que si x, y sont dans la même projection EXACTE
# si x, y = grille projetée LAEA → OK
# sinon lat/lon → il faut PlateCarree()
ax.pcolormesh(
    x, y, data_hdf5_plot,
    transform=proj,
    norm=log_norm,
    cmap="turbo"
)

ax.coastlines()

plt.title(plot_title)
plt.xlabel("x")
plt.ylabel("y")

plt.show()
# Out:
# <class 'cartopy.crs.LambertAzimuthalEqualArea'>
# +proj=laea +ellps=WGS84 +lon_0=10.0 +lat_0=55.0 +x_0=1950000.0 +y_0=-2100000.0 +no_defs +type=crs

# %% [markdown]
# ## 3b - Plot du NetCDF en (x,y)

# %%
ds = xr.open_dataset(output_netcdf)
data_netcdf = ds[varname_out]

# %%
# éviter les valeurs nulles, négatives et les Nan
data_netcdf_plot = data_netcdf.where((data_netcdf > 0) & (data_netcdf != FILL))

# %%
#data_netcdf = data_plot.to_numpy()
data_netcdf_np = data_netcdf.to_numpy()

# %%
plot_label = f"{varname_out} (mm/h)"
plot_title = f"NetCDF data : Rainfall (log scale)"

diff_norm = colors.LogNorm(vmin=0.01, vmax=120)

# %%
plt.figure()

plt.imshow(
    data_netcdf_plot, 
    origin="upper", # important !
    norm=diff_norm,
    cmap="turbo",
    aspect="equal"
     ) 

cbar = plt.colorbar()
cbar.set_label(plot_label)
plt.title(plot_title)
plt.xlabel("x")
plt.ylabel("y")
    
plt.show()

# %% [markdown]
# ## 3b - Plot du NetCDF en (lon,lat)

# %%
lon = ds["lon"]
lat = ds["lat"]

# %%
plt.figure()

plt.pcolormesh(
    lon, lat, data_netcdf_plot, 
    #origin="upper", # important !
    norm=log_norm,
    cmap="turbo",
    ) 

cbar = plt.colorbar()
cbar.set_label(plot_label)
plt.title(plot_title)
plt.xlabel("lon")
plt.ylabel("lat")
    
plt.show()

# %% [markdown]
# ### Ajout des contours des contients sur le plot NetCDF (lon,lat)

# %%
proj = ccrs.PlateCarree()

fig = plt.figure(figsize=(12, 6))
ax = plt.axes(projection=proj)

im = ax.pcolormesh(
    lon, lat, data_netcdf_plot,
    norm=log_norm,
    cmap="turbo",
    transform=proj)

ax.coastlines()
plt.colorbar(im)
    
plt.show()

# %% [markdown]
# ## 3d - Plot diff (Netcdf - HDF5)

# %%
data_hdf5
# Out:
# array([[-9999000., -9999000., -9999000., ..., -9999000., -9999000.,
#         -9999000.],
#        [-9999000., -9999000., -9999000., ..., -9999000., -9999000.,
#         -9999000.],
#        [-9999000., -9999000., -9999000., ..., -9999000., -9999000.,
#         -9999000.],
#        ...,
#        [-9999000., -9999000., -9999000., ..., -9999000., -9999000.,
#         -9999000.],
#        [-9999000., -9999000., -9999000., ..., -9999000., -9999000.,
#         -9999000.],
#        [-9999000., -9999000., -9999000., ..., -9999000., -9999000.,
#         -9999000.]], shape=(2200, 1900))

# %%
data_netcdf_np
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]],
#       shape=(2200, 1900), dtype=float32)

# %%
plot_label = f"{varname_out} (mm/h)"
plot_title = f"Diff (NETCDF - HDF5)"

diff_norm = colors.TwoSlopeNorm(vmin=-1.E-8, vcenter=0, vmax=+1.E-8)
#diff_norm = colors.TwoSlopeNorm(vmin=-1., vcenter=0, vmax=+1.)

# %%
plt.figure()

data_diff = data_netcdf_np - data_hdf5

data_diff_plot = data_diff.astype(float)
data_diff_plot[(data_diff == 0)] = np.nan
#data_plot[(data <= 0) | (data == FILL)] = np.nan

m = plt.pcolormesh(
    lon, lat, data_diff_plot,
    cmap="RdBu_r",
    norm=diff_norm,
    shading="auto"
)

cbar = plt.colorbar()
cbar.set_label(plot_label)
plt.title(plot_title)
plt.xlabel("lon")
plt.ylabel("lat")
 
plt.show()

# %% [markdown]
# ## 4 - Conversion NetCDF (toutes les échéances horaires du mois)

# %%
# utilisation des oordonnées lat/lon ou x/y
latlon_coords = True

# utilisation des lat/lon exactes fournies avec EURADCLIM
latlon_exact = True

# test seulement sur un échantillon du jeu de données
test = False

if not test:
    #list_of_fnames_in = sorted(glob.glob(f"{PROD}_{VAR}_{YEAR}{MONTH}*.h5"))
    lof = [f.name for f in Path(pi).glob(f"{PROD}_{VAR}_{YEAR}{MONTH}*.h5")]
    list_of_fnames_in = sorted(lof)
else:
    list_of_fnames_in = ["RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_201301231500.h5",
                         "RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_201301231600.h5", 
                         "RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_201301231700.h5",
                         "RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_201301231800.h5",]
    # Date     Time   Level Gridsize    Miss :     Minimum        Mean     Maximum : Parameter name
    # 2013-01-23 15:00:00       0  4180000 2303746 :      0.0000    0.072746      120.95 : HOURLY_RAINFALL_ACCUMULATION
    # 2013-01-23 16:00:00       0  4180000 2447877 :      0.0000    0.063897      43.181 : HOURLY_RAINFALL_ACCUMULATION
    # 2013-01-23 17:00:00       0  4180000 2298585 :      0.0000    0.086475      181.40 : HOURLY_RAINFALL_ACCUMULATION
    # 2013-01-23 18:00:00       0  4180000 2413985 :      0.0000    0.086906      132.90 : HOURLY_RAINFALL_ACCUMULATION

# -------------------------
# 1. Lecture HDF5
# -------------------------

# Nom de la variable d'entrée (HDF5) = nom générique
varname_in = "variable"
varname_out = VAR

data_list = []
time_list = []

for fname_in in list_of_fnames_in:
    
    print(fname_in)
    
    # time from filename
    timestamp = fname_in.split("_")[-1].replace(".h5", "")
    time = pd.to_datetime(timestamp, format="%Y%m%d%H%M")
    
    input_hdf5 = '/'.join([path_in, fname_in])
    
    with h5py.File(input_hdf5, "r") as f:
        data = f["dataset1/data1/data"][:]
        where = dict(f["where"].attrs)
    ###print(where)

    # gestion des Nan
    fill = -9.9990e+06
    data = data.astype("float32")
    data[data == fill] = np.nan
    
    # Création d'une variable time au standard
    time = pd.to_datetime(timestamp, format="%Y%m%d%H%M")
    
    # increment de la série temporelle
    #d = da.from_array(data, chunks=(200, 200))  # à adapter
    data_list.append(data)
    time_list.append(time)
        
# -------------------------
# 2. stack time
# -------------------------

data_stack = da.stack(data_list, axis=0)

#nt, ny, nx = data_stack.shape


# -------------------------
# 3. Grille
# -------------------------

# ajuster si besoin après test visuel
# data = data[::-1, :]
# y = y[::-1]

# -------------------------
# 4. Projection → lat/lon
# -------------------------

if latlon_exact:
    lon = copy.deepcopy(lon_exact)
    lat = copy.deepcopy(lat_exact)  
else:
    lon = copy.deepcopy(lon_rebuilt)
    lat = copy.deepcopy(lat_rebuilt)

# -------------------------
# 5. Dataset xarray
# -------------------------

if latlon_coords:     
    ds = xr.Dataset(
        data_vars=dict(
            variable=(("time", "y", "x"), data_stack)
         ),
        coords=dict(
             time=("time", time_list),
             lon=(("y", "x"), lon),
             lat=(("y", "x"), lat),
         ),
      )
else:
    ds = xr.Dataset(
        data_vars=dict(
             variable=(("y", "x"), data)
        ),
        coords=dict(
            time=("time", [time]),
            x=("x", x),
            y=("y", y),
        ),
    )

# -------------------------
# 5. Attributs CF
# -------------------------

if latlon_coords:  
    ds["lon"].attrs = {
        "standard_name": "longitude",
        "units": "degrees_east"
    }

    ds["lat"].attrs = {
         "standard_name": "latitude",
         "units": "degrees_north"
     }
else:
    ds["x"].attrs = {
         "standard_name": "projection_x_coordinate",
         "units": "m"
    }
    
    ds["y"].attrs = {
         "standard_name": "projection_y_coordinate",
         "units": "m"
     }


CF_VARIABLES = {
      "HOURLY_RAINFALL_ACCUMULATION": {
         "standard_name": "lwe_thickness_of_precipitation_amount",
         "long_name": "Hourly accumulated rainfall",
         "units": "kg m-2",
         "grid_mapping": "crs",
         "coordinates": "lat lon"
     }
}

ds = ds.rename({varname_in: varname_out})

attrs = CF_VARIABLES[varname_out]

ds[varname_out].attrs.update(attrs)

# -------------------------
# 6. CRS
# -------------------------

ds["crs"] = xr.DataArray()
ds["crs"].attrs = {
     "grid_mapping_name": "lambert_azimuthal_equal_area",
    "spatial_ref": proj4
}

# -------------------------
# 7. Export
# -------------------------

ds.to_netcdf(output_netcdf_ts, format="NETCDF4",
    #encoding={
    #    varname_out: {"zlib": True, "complevel": 4, "chunksizes": (1, ny, nx)}
    #    varname_out: {"zlib": True, "complevel": 4}
    #}
)
# Out:
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010010000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010010100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010010200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010010300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010010400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010010500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010010600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010010700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010010800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010010900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010011000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010011100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010011200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010011300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010011400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010011500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010011600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010011700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010011800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010011900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010012000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010012100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010012200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010012300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010020000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010020100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010020200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010020300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010020400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010020500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010020600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010020700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010020800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010020900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010021000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010021100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010021200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010021300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010021400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010021500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010021600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010021700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010021800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010021900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010022000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010022100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010022200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010022300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010030000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010030100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010030200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010030300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010030400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010030500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010030600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010030700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010030800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010030900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010031000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010031100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010031200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010031300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010031400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010031500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010031600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010031700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010031800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010031900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010032000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010032100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010032200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010032300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010040000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010040100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010040200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010040300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010040400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010040500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010040600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010040700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010040800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010040900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010041000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010041100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010041200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010041300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010041400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010041500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010041600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010041700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010041800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010041900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010042000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010042100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010042200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010042300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010050000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010050100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010050200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010050300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010050400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010050500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010050600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010050700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010050800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010050900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010051000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010051100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010051200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010051300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010051400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010051500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010051600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010051700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010051800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010051900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010052000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010052100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010052200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010052300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010060000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010060100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010060200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010060300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010060400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010060500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010060600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010060700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010060800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010060900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010061000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010061100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010061200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010061300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010061400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010061500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010061600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010061700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010061800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010061900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010062000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010062100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010062200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010062300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010070000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010070100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010070200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010070300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010070400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010070500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010070600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010070700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010070800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010070900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010071000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010071100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010071200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010071300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010071400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010071500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010071600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010071700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010071800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010071900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010072000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010072100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010072200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010072300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010080000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010080100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010080200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010080300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010080400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010080500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010080600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010080700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010080800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010080900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010081000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010081100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010081200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010081300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010081400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010081500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010081600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010081700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010081800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010081900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010082000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010082100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010082200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010082300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010090000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010090100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010090200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010090300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010090400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010090500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010090600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010090700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010090800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010090900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010091000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010091100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010091200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010091300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010091400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010091500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010091600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010091700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010091800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010091900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010092000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010092100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010092200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010092300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010100000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010100100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010100200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010100300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010100400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010100500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010100600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010100700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010100800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010100900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010101000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010101100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010101200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010101300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010101400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010101500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010101600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010101700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010101800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010101900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010102000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010102100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010102200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010102300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010110000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010110100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010110200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010110300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010110400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010110500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010110600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010110700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010110800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010110900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010111000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010111100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010111200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010111300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010111400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010111500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010111600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010111700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010111800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010111900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010112000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010112100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010112200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010112300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010120000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010120100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010120200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010120300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010120400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010120500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010120600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010120700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010120800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010120900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010121000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010121100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010121200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010121300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010121400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010121500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010121600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010121700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010121800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010121900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010122000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010122100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010122200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010122300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010130000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010130100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010130200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010130300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010130400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010130500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010130600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010130700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010130800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010130900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010131000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010131100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010131200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010131300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010131400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010131500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010131600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010131700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010131800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010131900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010132000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010132100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010132200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010132300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010140000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010140100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010140200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010140300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010140400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010140500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010140600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010140700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010140800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010140900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010141000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010141100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010141200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010141300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010141400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010141500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010141600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010141700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010141800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010141900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010142000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010142100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010142200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010142300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010150000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010150100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010150200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010150300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010150400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010150500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010150600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010150700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010150800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010150900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010151000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010151100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010151200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010151300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010151400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010151500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010151600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010151700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010151800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010151900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010152000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010152100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010152200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010152300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010160000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010160100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010160200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010160300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010160400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010160500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010160600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010160700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010160800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010160900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010161000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010161100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010161200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010161300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010161400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010161500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010161600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010161700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010161800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010161900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010162000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010162100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010162200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010162300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010170000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010170100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010170200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010170300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010170400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010170500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010170600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010170700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010170800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010170900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010171000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010171100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010171200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010171300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010171400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010171500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010171600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010171700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010171800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010171900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010172000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010172100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010172200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010172300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010180000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010180100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010180200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010180300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010180400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010180500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010180600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010180700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010180800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010180900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010181000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010181100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010181200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010181300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010181400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010181500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010181600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010181700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010181800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010181900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010182000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010182100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010182200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010182300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010190000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010190100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010190200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010190300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010190400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010190500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010190600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010190700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010190800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010190900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010191000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010191100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010191200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010191300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010191400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010191500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010191600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010191700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010191800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010191900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010192000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010192100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010192200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010192300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010200000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010200100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010200200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010200300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010200400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010200500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010200600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010200700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010200800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010200900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010201000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010201100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010201200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010201300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010201400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010201500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010201600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010201700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010201800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010201900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010202000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010202100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010202200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010202300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010210000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010210100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010210200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010210300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010210400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010210500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010210600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010210700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010210800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010210900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010211000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010211100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010211200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010211300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010211400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010211500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010211600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010211700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010211800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010211900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010212000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010212100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010212200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010212300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010220000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010220100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010220200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010220300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010220400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010220500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010220600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010220700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010220800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010220900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010221000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010221100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010221200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010221300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010221400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010221500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010221600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010221700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010221800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010221900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010222000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010222100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010222200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010222300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010230000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010230100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010230200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010230300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010230400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010230500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010230600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010230700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010230800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010230900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010231000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010231100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010231200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010231300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010231400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010231500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010231600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010231700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010231800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010231900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010232000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010232100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010232200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010232300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010240000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010240100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010240200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010240300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010240400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010240500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010240600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010240700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010240800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010240900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010241000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010241100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010241200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010241300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010241400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010241500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010241600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010241700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010241800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010241900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010242000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010242100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010242200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010242300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010250000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010250100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010250200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010250300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010250400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010250500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010250600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010250700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010250800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010250900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010251000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010251100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010251200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010251300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010251400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010251500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010251600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010251700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010251800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010251900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010252000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010252100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010252200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010252300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010260000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010260100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010260200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010260300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010260400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010260500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010260600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010260700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010260800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010260900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010261000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010261100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010261200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010261300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010261400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010261500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010261600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010261700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010261800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010261900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010262000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010262100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010262200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010262300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010270000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010270100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010270200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010270300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010270400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010270500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010270600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010270700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010270800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010270900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010271000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010271100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010271200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010271300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010271400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010271500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010271600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010271700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010271800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010271900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010272000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010272100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010272200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010272300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010280000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010280100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010280200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010280300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010280400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010280500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010280600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010280700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010280800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010280900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010281000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010281100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010281200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010281300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010281400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010281500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010281600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010281700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010281800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010281900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010282000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010282100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010282200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010282300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010290000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010290100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010290200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010290300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010290400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010290500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010290600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010290700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010290800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010290900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010291000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010291100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010291200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010291300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010291400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010291500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010291600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010291700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010291800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010291900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010292000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010292100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010292200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010292300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010300000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010300100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010300200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010300300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010300400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010300500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010300600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010300700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010300800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010300900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010301000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010301100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010301200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010301300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010301400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010301500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010301600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010301700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010301800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010301900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010302000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010302100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010302200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010302300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010310000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010310100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010310200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010310300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010310400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010310500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010310600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010310700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010310800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010310900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010311000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010311100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010311200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010311300.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010311400.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010311500.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010311600.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010311700.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010311800.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010311900.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010312000.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010312100.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010312200.h5
# RAD_OPERA_HOURLY_RAINFALL_ACCUMULATION_202010312300.h5

# %% [markdown]
# ## 4a - Plot carte d'une échéance temporelle (toujour la même pour vérif)

# %%
plot_label = "Rainfall (mm/h)"
plot_title = "Raw HDF5 data : Rainfall (log scale)"
log_norm = colors.LogNorm(vmin=0.01, vmax=120)

# %%
ds = xr.open_dataset(output_netcdf_ts)

data = ds[varname_out].sel(time=ECHEANCE)

plt.figure()

# éviter les valeurs nulles, négatives et les Nan
data_plot = data.where((data > 0) & (data != FILL))

proj = ccrs.PlateCarree()

fig = plt.figure(figsize=(12, 6))
ax = plt.axes(projection=proj)

im = ax.pcolormesh(
    lon, lat, data_netcdf_plot,
    norm=log_norm,
    cmap="turbo",
    transform=proj)

ax.coastlines()
plt.colorbar(im)
    
plt.show()

# %% [markdown]
# ## 4b - Plot série temporelle de la moyenne spatiale

# %%
ds = xr.open_dataset(output_netcdf_ts)

# moyenne spatiale
ts = ds[varname_out].mean(dim=["y", "x"])

plt.figure(figsize=(10,4))
plt.plot(ds["time"], ts)

plt.title("Rainfall time series (spatial mean)")
plt.xlabel("Time")
plt.ylabel(varname_out)
plt.grid()
plt.show()
